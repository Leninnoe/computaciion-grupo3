# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos proporcionados
datos = np.array([50, 14, 6, 73, 61, 72, 64, 83, 145, 189, 133, 273, 268, 199, 279, 258, 262, 342, 302, 393, 279, 313, 270, 399, 395, 498, 395, 255, 281, 361, 325, 503, 414, 447, 327, 388, 294, 433, 485, 463, 521, 442, 451, 521, 489, 1107, 954, 1396, 1197, 949, 1342, 1001, 1502, 1360, 1216, 1616, 1166, 1627, 2629, 2628, 2471, 1855, 2322, 2247, 3489, 4007, 3933, 4245, 3505, 3678, 4864, 3933, 4297, 4623, 3664, 4189, 4799, 5440, 3496, 4911, 4633, 4176, 5215, 6374, 4665, 3882, 5706, 5565, 6723, 6478, 6907, 5112, 4982, 36148, 4444, 6259, 5324, 5576, 4577, 3773, 3618, 4617, 4265, 4375, 4185, 3986, 3363, 2619, 2467, 3517, 3727, 3654, 2994, 2431, 2033, 3102, 3027, 2724, 2981, 2585, 1805, 1681, 2462, 2810, 2276, 2053, 2068, 1623, 1688, 2326, 2514, 2257, 2167, 2102, 1846, 1744, 1930, 2100, 1960, 2042, 1731, 1438, 1730, 1917, 2123, 2167, 2002, 1957, 1541, 1521, 1835, 2046, 1760, 2013, 1525, 1322, 1151, 1781, 1889, 1908, 1926, 1872, 1386, 1349, 1706, 1839, 2006, 1934, 1721, 1388, 1563, 1731, 1937, 1934, 2045, 1733, 1236, 1455, 1611, 1835, 2100, 2051, 1654, 1519, 1273, 1832, 1646, 1816, 1569, 1163, 1024, 1349, 1700, 2203, 2080, 1891, 1739, 1598])

# Definir grados del polinomio
grados = 3

# Ajuste polinómico
coeffs = np.polyfit(np.arange(len(datos)), datos, grados)

# Crear un polinomio a partir de los coeficientes
polinomio = np.poly1d(coeffs)

# Generar datos para el ajuste polinómico
x_fit = np.linspace(0, len(datos)-1, 100)
y_fit = polinomio(x_fit)

# Graficar datos y ajuste polinómico
plt.figure(figsize=(10, 6))
plt.scatter(np.arange(len(datos)), datos, label='Datos', color='blue')
plt.plot(x_fit, y_fit, label=f'Ajuste Polinómico (Grado {grados})', color='red')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.title('Ajuste Polinómico en Numpy con Matplotlib')
plt.legend()
plt.grid(True)
plt.show()
